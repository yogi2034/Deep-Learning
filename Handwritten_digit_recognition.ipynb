# %% [markdown]
# <a href="https://colab.research.google.com/github/yogi2034/Deep-Learning/blob/main/Handwritten_digit_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import datasets,layers,models

# %%
(X_train,Y_train),(X_test,Y_test)=keras.datasets.mnist.load_data()

len(X_train)

len(X_test)

X_train[0]
X_train=X_train/255
X_test=X_test/255
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
plt.matshow(X_train[49])

# %%
Y_train[:6]

X_train.shape

X_train_flatten=X_train.reshape(len(X_train),28*28)

# %%
X_train_flatten.shape

X_test_flatten=X_test.reshape(len(X_test),28*28)

# %%
model = keras.Sequential([
    keras.layers.Dense(10,input_shape=(784,),activation='sigmoid')
])
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model.fit(X_train_flatten,Y_train,epochs=5)

model.evaluate(X_test_flatten,Y_test)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4676 - accuracy: 0.8779
# Epoch 2/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3038 - accuracy: 0.9149
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2833 - accuracy: 0.9207
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2733 - accuracy: 0.9236
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2664 - accuracy: 0.9258
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2678 - accuracy: 0.9253
# [0.26782655715942383, 0.9253000020980835]

# %%
plt.matshow(X_test[2])

# %%
y_pred=model.predict(X_test_flatten)

y_pred[2]

np.argmax(y_pred[2])

y_pred_labels=[np.argmax(i) for i in y_pred]
y_pred_labels[:5]
# Out:
# 313/313 [==============================] - 1s 1ms/step
# [7, 2, 1, 0, 4]

# %%
cm=tf.math.confusion_matrix(labels=Y_test,predictions=y_pred_labels)
cm
# Out:
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[ 951,    0,    3,    2,    0,    5,   12,    3,    3,    1],
#        [   0, 1112,    3,    2,    0,    1,    4,    2,   11,    0],
#        [   3,    8,  931,   14,    9,    3,   13,   11,   36,    4],
#        [   1,    0,   20,  932,    0,   18,    3,   10,   17,    9],
#        [   1,    1,    2,    1,  919,    0,   13,    4,    8,   33],
#        [   8,    1,    3,   42,   11,  753,   20,    9,   37,    8],
#        [   7,    3,    5,    1,    7,    7,  925,    2,    1,    0],
#        [   1,    5,   21,    9,    8,    0,    0,  949,    2,   33],
#        [   4,    9,    7,   29,    9,   18,   12,   12,  865,    9],
#        [   8,    7,    2,   10,   34,    5,    0,   22,    5,  916]],
#       dtype=int32)>

# %%
Y_test.shape
# Out:
# (10000,)

# %%
import seaborn as sns
plt.figure(figsize=(10,7))
sns.heatmap(cm,annot=True,fmt='d')
plt.xlabel('predicted')
plt.ylabel('Original')
# Out:
# Text(95.72222222222221, 0.5, 'Original')

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(100,activation='sigmoid'),
    keras.layers.Dense(50,activation='sigmoid'),
    keras.layers.Dense(25,activation='sigmoid'),
    keras.layers.Dense(10,activation='relu')

])
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model.fit(X_train,Y_train,epochs=5)

model.evaluate(X_test,Y_test)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 2.3538 - accuracy: 0.0989
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.3026 - accuracy: 0.0987
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 2.3026 - accuracy: 0.0987
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.3026 - accuracy: 0.0987
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 2.3026 - accuracy: 0.0987
# 313/313 [==============================] - 1s 2ms/step - loss: 2.3026 - accuracy: 0.0980
# [2.30259108543396, 0.09799999743700027]

# %%
cm=tf.math.confusion_matrix(labels=Y_test,predictions=y_pred_labels)
cm
# Out:
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[ 951,    0,    3,    2,    0,    5,   12,    3,    3,    1],
#        [   0, 1112,    3,    2,    0,    1,    4,    2,   11,    0],
#        [   3,    8,  931,   14,    9,    3,   13,   11,   36,    4],
#        [   1,    0,   20,  932,    0,   18,    3,   10,   17,    9],
#        [   1,    1,    2,    1,  919,    0,   13,    4,    8,   33],
#        [   8,    1,    3,   42,   11,  753,   20,    9,   37,    8],
#        [   7,    3,    5,    1,    7,    7,  925,    2,    1,    0],
#        [   1,    5,   21,    9,    8,    0,    0,  949,    2,   33],
#        [   4,    9,    7,   29,    9,   18,   12,   12,  865,    9],
#        [   8,    7,    2,   10,   34,    5,    0,   22,    5,  916]],
#       dtype=int32)>

# %%
import seaborn as sns
plt.figure(figsize=(10,7))
sns.heatmap(cm,annot=True,fmt='d')
plt.xlabel('predicted')
plt.ylabel('Original')
# Out:
# Text(95.72222222222221, 0.5, 'Original')

# %%
cnn = models.Sequential([
    layers.Conv2D(30, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.MaxPooling2D((2, 2)),


    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])
cnn.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
cnn.fit(X_train, Y_train, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.1673 - accuracy: 0.9507
# Epoch 2/10
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0595 - accuracy: 0.9819
# Epoch 3/10
# 1875/1875 [==============================] - 31s 17ms/step - loss: 0.0409 - accuracy: 0.9876
# Epoch 4/10
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0295 - accuracy: 0.9910
# Epoch 5/10
# 1875/1875 [==============================] - 31s 17ms/step - loss: 0.0209 - accuracy: 0.9934
# Epoch 6/10
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0150 - accuracy: 0.9954
# Epoch 7/10
# 1875/1875 [==============================] - 31s 16ms/step - loss: 0.0115 - accuracy: 0.9962
# Epoch 8/10
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0086 - accuracy: 0.9971
# Epoch 9/10
# 1321/1875 [====================>.........] - ETA: 9s - loss: 0.0064 - accuracy: 0.9980

# %%
cnn.evaluate(X_test,Y_test)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0600 - accuracy: 0.9860
# [0.05996008217334747, 0.9860000014305115]

# %%
cnn.predict(X_test)
# Out:
# 313/313 [==============================] - 3s 9ms/step
# array([[4.0665899e-12, 3.8875705e-11, 5.2350776e-12, ..., 9.9999994e-01,
#         3.4143556e-12, 1.3915766e-10],
#        [2.1861277e-10, 1.3610466e-08, 9.9999994e-01, ..., 8.5795710e-14,
#         2.7415150e-11, 2.0171117e-17],
#        [6.9071904e-09, 9.9999994e-01, 4.6300364e-10, ..., 1.7208752e-08,
#         1.2344598e-09, 2.2199122e-12],
#        ...,
#        [1.2649860e-16, 2.8979208e-11, 5.9658046e-17, ..., 3.1133680e-09,
#         4.0369186e-10, 1.5021440e-10],
#        [1.5677574e-11, 6.5448945e-11, 5.8172529e-15, ..., 5.8139253e-15,
#         1.7080619e-06, 6.5525818e-13],
#        [2.1813234e-19, 5.4442080e-17, 5.5930200e-15, ..., 5.1828712e-22,
#         8.8914056e-15, 7.9530438e-23]], dtype=float32)
