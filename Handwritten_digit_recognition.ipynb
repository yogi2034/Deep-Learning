# %% [markdown]
# <a href="https://colab.research.google.com/github/yogi2034/Deep-Learning/blob/main/Handwritten_digit_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
# Out:
# hsn

# %%
(X_train,Y_train),(X_test,Y_test)=keras.datasets.mnist.load_data()

len(X_train)

len(X_test)

X_train[0]
X_train=X_train/255
X_test=X_test/255
# Out:
# f

# %%
plt.matshow(X_train[49])

# %%
Y_train[:6]

X_train.shape

X_train_flatten=X_train.reshape(len(X_train),28*28)

# %%
X_train_flatten.shape

X_test_flatten=X_test.reshape(len(X_test),28*28)
# Out:
# f

# %%
model = keras.Sequential([
    keras.layers.Dense(10,input_shape=(784,),activation='sigmoid')
])
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model.fit(X_train_flatten,Y_train,epochs=5)

model.evaluate(X_test_flatten,Y_test)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.4689 - accuracy: 0.8774
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3046 - accuracy: 0.9151
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2836 - accuracy: 0.9208
# Epoch 4/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2732 - accuracy: 0.9233
# Epoch 5/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2667 - accuracy: 0.9256
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2700 - accuracy: 0.9257
# [0.2700127065181732, 0.9257000088691711]

# %%
plt.matshow(X_test[2])

# %%
y_pred=model.predict(X_test_flatten)

y_pred[2]

np.argmax(y_pred[2])

y_pred_labels=[np.argmax(i) for i in y_pred]
y_pred_labels[:5]
# Out:
# 313/313 [==============================] - 1s 3ms/step
# [7, 2, 1, 0, 4]

# %%
cm=tf.math.confusion_matrix(labels=Y_test,predictions=y_pred_labels)
cm
# Out:
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[ 969,    0,    0,    1,    0,    4,    2,    2,    2,    0],
#        [   0, 1112,    3,    2,    0,    1,    4,    2,   11,    0],
#        [  12,    8,  922,   13,    9,    2,   11,    9,   42,    4],
#        [   5,    0,   21,  910,    0,   25,    2,   13,   27,    7],
#        [   1,    1,    3,    1,  923,    0,   11,    4,   10,   28],
#        [  14,    3,    5,   29,   12,  768,   14,    8,   34,    5],
#        [  16,    3,    8,    1,    8,    9,  909,    1,    3,    0],
#        [   2,    6,   22,    4,    8,    0,    0,  950,    3,   33],
#        [   8,    7,    7,   15,    9,   17,    9,   13,  883,    6],
#        [  11,    7,    1,    8,   33,    7,    0,   24,    7,  911]])>

# %%
Y_test.shape
# Out:
# (10000,)

# %%
import seaborn as sns
plt.figure(figsize=(10,7))
sns.heatmap(cm,annot=True,fmt='d')
plt.xlabel('predicted')
plt.ylabel('Original')
# Out:
# Text(95.72222222222221, 0.5, 'Original')

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(100,activation='sigmoid'),
    keras.layers.Dense(50,activation='sigmoid'),
    keras.layers.Dense(25,activation='sigmoid'),
    keras.layers.Dense(10,activation='relu')

])
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model.fit(X_train,Y_train,epochs=5)

model.evaluate(X_test,Y_test)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 14s 6ms/step - loss: 8.6260 - accuracy: 0.1004
# Epoch 2/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 8.5197 - accuracy: 0.1514
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 3.4101 - accuracy: 0.1855
# Epoch 4/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 2.1325 - accuracy: 0.1734
# Epoch 5/5
# 1875/1875 [==============================] - 10s 6ms/step - loss: 2.2639 - accuracy: 0.1153
# 313/313 [==============================] - 2s 4ms/step - loss: 2.0103 - accuracy: 0.1979
# [2.010260820388794, 0.19789999723434448]

# %%
cm=tf.math.confusion_matrix(labels=Y_test,predictions=y_pred_labels)
cm
# Out:
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[ 969,    0,    0,    1,    0,    4,    2,    2,    2,    0],
#        [   0, 1112,    3,    2,    0,    1,    4,    2,   11,    0],
#        [  12,    8,  922,   13,    9,    2,   11,    9,   42,    4],
#        [   5,    0,   21,  910,    0,   25,    2,   13,   27,    7],
#        [   1,    1,    3,    1,  923,    0,   11,    4,   10,   28],
#        [  14,    3,    5,   29,   12,  768,   14,    8,   34,    5],
#        [  16,    3,    8,    1,    8,    9,  909,    1,    3,    0],
#        [   2,    6,   22,    4,    8,    0,    0,  950,    3,   33],
#        [   8,    7,    7,   15,    9,   17,    9,   13,  883,    6],
#        [  11,    7,    1,    8,   33,    7,    0,   24,    7,  911]])>

# %%
import seaborn as sns
plt.figure(figsize=(10,7))
sns.heatmap(cm,annot=True,fmt='d')
plt.xlabel('predicted')
plt.ylabel('Original')
# Out:
# Text(95.72222222222221, 0.5, 'Original')
